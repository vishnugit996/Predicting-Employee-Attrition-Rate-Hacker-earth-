# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('hacker_train.csv')
train.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_23371      F  42.0                4             Married     Franklin
# 1   EID_18000      M  24.0                3              Single  Springfield
# 2    EID_3891      F  58.0                3             Married      Clinton
# 3   EID_17492      F  26.0                3              Single      Lebanon
# 4   EID_22534      F  31.0                1             Married  Springfield
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  ...  Compensation_and_Benefits  Work_Life_balance  \
# ...

# %%
plt.figure(figsize = (20, 10))
sns.heatmap(train.corr(), annot = True)
plt.show()

# %%
#dropping age due to high correlation with time_of_service
train.drop('Age', axis = 1 ,inplace = True)

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
train_mice = train.copy(deep=True)

mice_imputer = IterativeImputer()
train_mice['Age'] = mice_imputer.fit_transform(train_mice[['Age']])

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
train_mice1 = train_mice.copy(deep=True)

mice_imputer = IterativeImputer()
train_mice1['Time_of_service'] = mice_imputer.fit_transform(train_mice1[['Time_of_service']])

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
train_mice2 = train_mice1.copy(deep=True)

mice_imputer = IterativeImputer()
train_mice2['Work_Life_balance'] = mice_imputer.fit_transform(train_mice2[['Work_Life_balance']])

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
train_mice3 = train_mice2.copy(deep=True)

mice_imputer = IterativeImputer()
train_mice3['VAR2'] = mice_imputer.fit_transform(train_mice3[['VAR2']])

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
train_mice4 = train_mice3.copy(deep=True)

mice_imputer = IterativeImputer()
train_mice4['VAR4'] = mice_imputer.fit_transform(train_mice4[['VAR4']])

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
train_mice5 = train_mice4.copy(deep=True)

mice_imputer = IterativeImputer()
train_mice5['Pay_Scale'] = mice_imputer.fit_transform(train_mice5[['Pay_Scale']])

# %%
train_mice5.isnull().sum()
# Out:
# Employee_ID                  0
# Gender                       0
# Age                          0
# Education_Level              0
# Relationship_Status          0
# Hometown                     0
# Unit                         0
# Decision_skill_possess       0
# Time_of_service              0
# Time_since_promotion         0
# growth_rate                  0
# Travel_Rate                  0
# Post_Level                   0
# Pay_Scale                    0
# Compensation_and_Benefits    0
# Work_Life_balance            0
# VAR1                         0
# VAR2                         0
# VAR3                         0
# VAR4                         0
# VAR5                         0
# VAR6                         0
# VAR7                         0
# Attrition_rate               0
# dtype: int64

# %%
test = pd.read_csv('hacker_test.csv')
test.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_22713      F  32.0                5              Single  Springfield
# 1    EID_9658      M  65.0                2              Single      Lebanon
# 2   EID_22203      M  52.0                3             Married  Springfield
# 3    EID_7652      M  50.0                5              Single   Washington
# 4    EID_6516      F  44.0                3             Married     Franklin
#
#         Unit Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0        R&D             Conceptual              7.0                     4
# 1         IT              Directive             41.0                     2
# 2      Sales              Directive             21.0                     3
# 3  Marketing             Analytical             11.0                     4
# 4        R&D             Conceptual             12.0                     4
#
# ...

# %%
test.drop('Age', axis = 1 ,inplace = True)

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
test_mice = test.copy(deep=True)

mice_imputer = IterativeImputer()
test_mice['Age'] = mice_imputer.fit_transform(test_mice[['Age']])

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
test_mice1 = test_mice.copy(deep=True)

mice_imputer = IterativeImputer()
test_mice1['Time_of_service'] = mice_imputer.fit_transform(test_mice1[['Time_of_service']])

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
test_mice2 = test_mice1.copy(deep=True)

mice_imputer = IterativeImputer()
test_mice2['Work_Life_balance'] = mice_imputer.fit_transform(test_mice2[['Work_Life_balance']])

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
test_mice3 = test_mice2.copy(deep=True)

mice_imputer = IterativeImputer()
test_mice3['VAR2'] = mice_imputer.fit_transform(test_mice3[['VAR2']])

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
test_mice4 = test_mice3.copy(deep=True)

mice_imputer = IterativeImputer()
test_mice4['VAR4'] = mice_imputer.fit_transform(test_mice4[['VAR4']])

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
test_mice5 = test_mice4.copy(deep=True)

mice_imputer = IterativeImputer()
test_mice5['Pay_Scale'] = mice_imputer.fit_transform(test_mice5[['Pay_Scale']])

# %%
test_mice5.isnull().sum()
# Out:
# Employee_ID                  0
# Gender                       0
# Age                          0
# Education_Level              0
# Relationship_Status          0
# Hometown                     0
# Unit                         0
# Decision_skill_possess       0
# Time_of_service              0
# Time_since_promotion         0
# growth_rate                  0
# Travel_Rate                  0
# Post_Level                   0
# Pay_Scale                    0
# Compensation_and_Benefits    0
# Work_Life_balance            0
# VAR1                         0
# VAR2                         0
# VAR3                         0
# VAR4                         0
# VAR5                         0
# VAR6                         0
# VAR7                         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\vishnu reddy\Anaconda3\lib\site-packages\dask\config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# C:\Users\vishnu reddy\Anaconda3\lib\site-packages\dask\dataframe\utils.py:13: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# C:\Users\vishnu reddy\Anaconda3\lib\site-packages\distributed\config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
train_mice5.drop('Employee_ID',axis=1, inplace=True)
test_mice5.drop('Employee_ID',axis=1, inplace=True)

# %%
num_col = ['Education_Level','Time_of_service','Time_since_promotion','growth_rate','Travel_Rate','Post_Level','Pay_Scale','Work_Life_balance','VAR1','VAR2','VAR3','VAR4','VAR5','VAR6','VAR7']

# %%
cat_columns = [col for col in train_mice5.columns if train_mice5[col].dtype =='O' ]

# %%
encoder = LabelEncoder()

for col in cat_columns:
    train_mice5[col] = encoder.fit_transform(train_mice5[col])
    test_mice5[col] = encoder.transform(test_mice5[col])

# %%
scaler = StandardScaler()

for col in num_col:
    train_mice5[col] = scaler.fit_transform(train_mice5[col].values.reshape(-1, 1))
    test_mice5[col] = scaler.transform(test_mice5[col].values.reshape(-1, 1))

# %%
train_mice5.head()
# Out:
#    Gender   Age  Education_Level  Relationship_Status  Hometown  Unit  \
# 0       0  42.0         0.762557                    0         1     2
# 1       1  24.0        -0.176387                    1         3     3
# 2       0  58.0        -0.176387                    0         0     8
# 3       0  26.0        -0.176387                    1         2     1
# 4       0  31.0        -2.054275                    0         3     3
#
#    Decision_skill_possess  Time_of_service  Time_since_promotion  growth_rate  \
# 0                       2        -0.915055              1.420724    -0.892388
# 1                       0        -0.817554              1.420724    -0.702036
# 2                       2         1.327473              0.550639     0.249724
# 3                       1        -0.915055              0.550639     0.566977
# 4                       2        -0.817554              1.420724     0.947681
#
#    ...  Compensation_and_Benefits  Work_Life_balance      VAR1      VAR2  \
# ...

# %%
X = train_mice5.drop(['Attrition_rate'], axis=1)
y = train_mice5[['Attrition_rate']]
X_test = test_mice5
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.20, random_state=42, shuffle=True)

# %%
RF_reg=RandomForestRegressor(max_depth = 1, n_estimators= 307)
RF_reg.fit(X_train,y_train)
y_pred = RF_reg.predict(X_val)
rmse3 = np.sqrt(mean_squared_error(y_pred, y_val))
# Out:
# C:\Users\vishnu reddy\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
rmse3
# Out:
# 0.18655117127689047

# %%
RF_reg.fit(X, y)
predicts = RF_reg.predict(X_test)
# Out:
# C:\Users\vishnu reddy\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.

# %%
predicts
# Out:
# array([0.1908183 , 0.18868773, 0.18841719, ..., 0.18658447, 0.18513349,
#        0.19053898])

# %%
xgb_reg = XGBRegressor(learning_rate=0.1, max_depth=1, min_child_weight=1, seed=0)

xgb_reg.fit(X_train, y_train)
y_pred = xgb_reg.predict(X_val)
rmse = np.sqrt(mean_squared_error(y_pred, y_val))

# %%
rmse
# Out:
# 0.18645006390868732

# %%
xgb_reg.fit(X, y)
predict = xgb_reg.predict(X_test)

# %%
predict
# Out:
# array([0.198351  , 0.18197176, 0.18491778, ..., 0.17237175, 0.17404118,
#        0.19340917], dtype=float32)

# %%
from sklearn.linear_model import RidgeCV

ridge_cv = RidgeCV(alphas=(0.01,0.05,0.1,0.3,1,3,5,10))
y_pred1 = ridge_cv.fit(X, y)
ridge_cv_preds=ridge_cv.predict(X_test)

# %%
ridge_cv_preds
# Out:
# array([[0.20467424],
#        [0.20375506],
#        [0.19023673],
#        ...,
#        [0.17041122],
#        [0.16051396],
#        [0.18981099]])

# %%
test=pd.read_csv('hacker_test.csv')
test.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_22713      F  32.0                5              Single  Springfield
# 1    EID_9658      M  65.0                2              Single      Lebanon
# 2   EID_22203      M  52.0                3             Married  Springfield
# 3    EID_7652      M  50.0                5              Single   Washington
# 4    EID_6516      F  44.0                3             Married     Franklin
#
#         Unit Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0        R&D             Conceptual              7.0                     4
# 1         IT              Directive             41.0                     2
# 2      Sales              Directive             21.0                     3
# 3  Marketing             Analytical             11.0                     4
# 4        R&D             Conceptual             12.0                     4
#
# ...

# %%
test=test[['Employee_ID']]

# %%
test.head()
# Out:
#   Employee_ID
# 0   EID_22713
# 1    EID_9658
# 2   EID_22203
# 3    EID_7652
# 4    EID_6516

# %%
test['Attrition_rate']=predict
test.head()
# Out:
#   Employee_ID  Attrition_rate
# 0   EID_22713        0.198351
# 1    EID_9658        0.181972
# 2   EID_22203        0.184918
# 3    EID_7652        0.213959
# 4    EID_6516        0.194900

# %%
test.to_csv('employeehacker800.csv',index=False)

# %%
xgb_reg.fit(X, y)
predict = xgb_reg.predict(X_test)

# %%
test=pd.read_csv('hacker_test.csv')
test.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_22713      F  32.0                5              Single  Springfield
# 1    EID_9658      M  65.0                2              Single      Lebanon
# 2   EID_22203      M  52.0                3             Married  Springfield
# 3    EID_7652      M  50.0                5              Single   Washington
# 4    EID_6516      F  44.0                3             Married     Franklin
#
#         Unit Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0        R&D             Conceptual              7.0                     4
# 1         IT              Directive             41.0                     2
# 2      Sales              Directive             21.0                     3
# 3  Marketing             Analytical             11.0                     4
# 4        R&D             Conceptual             12.0                     4
#
# ...

# %%
test=test[['Employee_ID']]

# %%
test['Attrition_rate']=ridge_cv_preds
test.head()
# Out:
#   Employee_ID  Attrition_rate
# 0   EID_22713        0.204674
# 1    EID_9658        0.203755
# 2   EID_22203        0.190237
# 3    EID_7652        0.216152
# 4    EID_6516        0.197189

# %%
test.to_csv('employeehacker400.csv',index=False)

# %%
predicts
# Out:
# array([0.19173108, 0.18789964, 0.18909688, ..., 0.186144  , 0.18492756,
#        0.19155696])

# %%
ridge_cv_preds
# Out:
# array([[0.20467424],
#        [0.20375506],
#        [0.19023673],
#        ...,
#        [0.17041122],
#        [0.16051396],
#        [0.18981099]])

# %%
luck = (predicts + predict)/2

# %%
luck
# Out:
# array([0.19507579, 0.1851965 , 0.18705445, ..., 0.17953208, 0.17953187,
#        0.19225794])

# %%
test=pd.read_csv('hacker_test.csv')
test.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_22713      F  32.0                5              Single  Springfield
# 1    EID_9658      M  65.0                2              Single      Lebanon
# 2   EID_22203      M  52.0                3             Married  Springfield
# 3    EID_7652      M  50.0                5              Single   Washington
# 4    EID_6516      F  44.0                3             Married     Franklin
#
#         Unit Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0        R&D             Conceptual              7.0                     4
# 1         IT              Directive             41.0                     2
# 2      Sales              Directive             21.0                     3
# 3  Marketing             Analytical             11.0                     4
# 4        R&D             Conceptual             12.0                     4
#
# ...

# %%
test=test[['Employee_ID']]

# %%
test.shape
# Out:
# (3000, 1)

# %%
test['Attrition_rate']=luck
test.head()
# Out:
#   Employee_ID  Attrition_rate
# 0   EID_22713        0.195076
# 1    EID_9658        0.185196
# 2   EID_22203        0.187054
# 3    EID_7652        0.206443
# 4    EID_6516        0.193058

# %%
test.to_csv('employeehacker600.csv',index=False)
